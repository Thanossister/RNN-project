# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import pandas as pd
from pandas import DataFrame
import os

# %%
df = DataFrame()
# pred_name = 'Density'
pred_name = 'Tn'
fenzi_name = 'H2'

# %%
filePath = '../input/ctype3040'
result = os.listdir(filePath)
result = sorted(result)

results = []
results_full = []
# isSample = False
isSample = True

data_name = 'newNH3'
for j, namesda in enumerate(result):
    # names_use.append(namesda.split('.')[0].split('_')[0]+' '.join(namesda.split('.')[0].split('_')[2:-1]))
    aaaa = namesda.split('.')[0].split('_')
    if len(aaaa) <= 3:
        if aaaa[1] == data_name:
            results.append(namesda)
    elif len(aaaa) > 3:
        if aaaa[1] == data_name:
            results_full.append(namesda)
            
# results = results[:1]+results[3:]
# results = results[1:]

# %%
results

# %%
import time
from tqdm import tqdm

for i, fold_name in enumerate(tqdm(results)):
  if i == 3:
    continue
  else:
#     if not os.path.exists('../input/ctype3040/'+fold_name+'/H2_lev.out'):
#       continue
#     else:
      CO_cdens = pd.read_csv('../input/ctype3040/'+fold_name+'/H2_lev.out', header=None, engine='python')
#       CO_cdens = pd.read_csv(f'../input/ctype3040/'+fold_name+f'/{fenzi_name}_lev.out', header=None)
      # CO_cdens = pd.read_csv('/content/drive/MyDrive/CO_cdens = pd.read_csv('../input/ctype3040/'+fold_name+'/CO_lev.out', header=None, engine='python')NLU/grid/C-type/C-n3v10b01MRN_newNH3/H2_lev.out', header=None, engine='python')

      df_new = DataFrame()

      fi_result, line1, line2, line3, line4, line5, names, finalo = [], [], [], [], [], [], [], []

      for i, item in enumerate(CO_cdens[0]):
          if i == 0:
              remove_space = item.split(' ')
              remove_none = [x for x in remove_space if x !='']
              names.append(remove_none[:5])
          else:
            remove_space = item.split(' ')
#             print(i)
            remove_none = [np.float64(x) for x in remove_space if x !='']
            finalo.append(remove_none[:5])

          # print(remove_none[:3])

          if i == 0:
              names.append(remove_none[:5])
          else:
              fi_result.append(remove_none[:5])

      for j in fi_result:
          line1.append(j[0])
          line2.append(j[1])
          line3.append(j[2])
          line4.append(j[3])
          line5.append(j[4])

      line1, line2, line3, line4, line5 = pd.Series(line1), pd.Series(line2), pd.Series(line3), pd.Series(line4), pd.Series(line5)

      df_new.insert(0, 'distance', line1)
      df_new.insert(1, 'timeN', line2)
      if pred_name == 'Tn':
          df_new.insert(2, f'{pred_name}', line3)
      elif pred_name == '(0,0)':
          df_new.insert(2, f'{pred_name}', line4)
      else:
          df_new.insert(2, f'{pred_name}', line5)
            
      fig = plt.figure(figsize = (10,4))
      ax1 = fig.add_subplot(1,2,1)
      ax1.scatter(df_new['distance'], df_new[f'{pred_name}'])
      plt.xlabel('distance')
      plt.ylabel(f'{pred_name}')
      plt.grid()
      # 正线性相关

      ax2 = fig.add_subplot(1,2,2)
      ax2.scatter(df_new['timeN'], df_new[f'{pred_name}'])
      plt.xlabel('timeN')
      plt.ylabel(f'{pred_name}')
      plt.grid()
#       plt.savefig('./sandiantu.png', dpi=300)
      df = df.append(df_new)

# %%
df

# %%
# filePath = '../input/ctype5060'
# result = os.listdir(filePath)
# result = sorted(result)

# results = []
# results_full = []
# # isSample = False
# isSample = True

# data_name = 'newNH3'
# # data_name = 'H&McK'
# for j, namesda in enumerate(result):
# #     names_use.append(namesda.split('.')[0].split('_')[0]+' '.join(namesda.split('.')[0].split('_')[2:-1]))
#     aaaa = namesda.split('.')[0].split('_')
#     if len(aaaa) <= 3:
#         if aaaa[1] == data_name:
#             results.append(namesda)
#     elif len(aaaa) > 3:
#         if aaaa[1] == data_name:
#             results_full.append(namesda)
            
# results

# %%
filePath = '../input/ctype5060'
result = os.listdir(filePath)
result = sorted(result)

results = []
results_full = []
# isSample = False
isSample = True

data_name = 'newNH3'
for j, namesda in enumerate(result):
#     names_use.append(namesda.split('.')[0].split('_')[0]+' '.join(namesda.split('.')[0].split('_')[2:-1]))
    aaaa = namesda.split('.')[0].split('_')
    if len(aaaa) <= 3:
        if aaaa[1] == data_name:
            results.append(namesda)
    elif len(aaaa) > 3:
        if aaaa[1] == data_name:
            results_full.append(namesda)
            
# results = results[:-1]

# %%
# results = results[:-5]
# results

# %%
import time
from tqdm import tqdm

for i, fold_name in enumerate(tqdm(results)):
  if i == 3:
    continue
  else:
    if not os.path.exists(f'../input/ctype5060/'+fold_name+f'/{fenzi_name}_lev.out'):
      continue
    else:
      CO_cdens = pd.read_csv(f'../input/ctype5060/'+fold_name+f'/{fenzi_name}_lev.out', header=None, engine='python')
#       CO_cdens = pd.read_csv('../input/ctype5060/'+fold_name+'/H2_lev.out', header=None, engine='python')
#       CO_cdens = pd.read_csv('../input/ctype5060/'+fold_name+'/SiO_lev.out', header=None, engine='python')
      # CO_cdens = pd.read_csv('/content/drive/MyDrive/NLU/grid/C-type/C-n3v10b01MRN_newNH3/H2_lev.out', header=None, engine='python')

      df_new = DataFrame()

      fi_result, line1, line2, line3, line4, line5, names, finalo = [], [], [], [], [], [], [], []

      for i, item in enumerate(CO_cdens[0]):
          if i == 0:
              remove_space = item.split(' ')
              remove_none = [x for x in remove_space if x !='']
              names.append(remove_none[:5])
          else:
            remove_space = item.split(' ')
            remove_none = [float(x) for x in remove_space if x !='']
            finalo.append(remove_none[:5])

          # print(remove_none[:3])

          if i == 0:
              names.append(remove_none[:5])
          else:
              fi_result.append(remove_none[:5])

      for j in fi_result:
          line1.append(j[0])
          line2.append(j[1])
          line3.append(j[2])
          line4.append(j[3])
          line5.append(j[4])

      line1, line2, line3, line4, line5 = pd.Series(line1), pd.Series(line2), pd.Series(line3), pd.Series(line4), pd.Series(line5)

      df_new.insert(0, 'distance', line1)
      df_new.insert(1, 'timeN', line2)
      if pred_name == 'Tn':
          df_new.insert(2, f'{pred_name}', line3)
      elif pred_name == '(0,0)':
          df_new.insert(2, f'{pred_name}', line4)
      else:
          df_new.insert(2, f'{pred_name}', line5)
      
      fig = plt.figure(figsize = (10,4))
      ax1 = fig.add_subplot(1,2,1)
      ax1.scatter(df_new['distance'], df_new[f'{pred_name}'])
      plt.xlabel('distance')
      plt.ylabel(f'{pred_name}')
      plt.grid()
      # 正线性相关

      ax2 = fig.add_subplot(1,2,2)
      ax2.scatter(df_new['timeN'], df_new[f'{pred_name}'])
      plt.xlabel('timeN')
      plt.ylabel(f'{pred_name}')
      plt.grid()
        
      df = df.append(df_new)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.dropna(axis=0, how='any')

# %%
df

# %%
features_3 = ['distance', 'timeN', f'{pred_name}']
features = df[features_3]


features.plot(subplots=True)
fig = plt.gcf()
fig.savefig('./c-type-one-density.png', dpi=300)

# %%
features

# %%
# fig = plt.figure(figsize = (10,4))
# ax1 = fig.add_subplot(1,2,1)
# ax1.scatter(features['distance'], features['Tn'])
# plt.grid()
# # 正线性相关

# ax2 = fig.add_subplot(1,2,2)
# ax2.scatter(features['timeN'], features['Tn'])
# plt.grid()

# %%
# pd.plotting.scatter_matrix(features,figsize=(8,8),#注意Pandas中的用法与之前不同
#                   c = 'k',
#                  marker = '+',
#                  diagonal='hist',
#                  alpha = 0.8,
#                  range_padding=0.1)
# plt.show()

# %%
test_split=round(len(df)*0.2)

# %%
test_split = test_split - 1000

# %%
df_for_training=df[:-test_split]
df_for_testing=df[-test_split:-1000]
df_30_days_future=df[-1000:]

# %%
print(df_for_training.shape)
print(df_for_testing.shape)
print(df_30_days_future.shape)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df_for_training_scaled = scaler.fit_transform(df_for_training)

# %%
scaler

# %%
df_for_testing_scaled=scaler.transform(df_for_testing)

# %%
df_for_training_scaled

# %%
back_num = 1000

# %%
def createXY(dataset,n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            dataY.append(dataset[i,2])
    return np.array(dataX),np.array(dataY)

# %%
# df_for_training_scaled = finalo[:-782, :]
trainX,trainY=createXY(df_for_training_scaled,back_num)

# %%
trainX.shape

# %%
# df_for_testing_scaled = finalo[-782:, :]
testX,testY=createXY(df_for_testing_scaled,back_num)

# %%
trainX[0].shape

# %%
print("trainX Shape-- ",trainX.shape)
print("trainY Shape-- ",trainY.shape)

# %%
print("testX Shape-- ",testX.shape)
print("testY Shape-- ",testY.shape)

# %%
print("trainX[0]-- \n",trainX[0])
print("\ntrainY[0]-- ",trainY[0])

# %%
trainY[0]

# %%
trainY.shape

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
def build_model(optimizer):
    grid_model = Sequential()
    grid_model.add(LSTM(100,return_sequences=True,input_shape=(back_num,3)))
    grid_model.add(LSTM(100))
    grid_model.add(Dropout(0.1))
    grid_model.add(Dropout(0.2))
    grid_model.add(Dropout(0.3))
    grid_model.add(Dropout(0.4))
    grid_model.add(Dropout(0.5))
    # grid_model.add(Dropout(0.1))
    grid_model.add(Dense(1))

    grid_model.compile(loss = 'mae',optimizer = optimizer)
    return grid_model

grid_model = KerasRegressor(build_fn=build_model,verbose=1,validation_data=(testX,testY))
parameters = {'batch_size' : [256],
# parameters = {'batch_size' : [20],
              'epochs' : [10],
              'optimizer' : ['adam'] }

grid_search  = GridSearchCV(estimator = grid_model,
                            param_grid = parameters,
                            cv = 3)

# %%
grid_search = grid_search.fit(trainX,trainY)

# %%
grid_search.best_params_

# %%
my_model=grid_search.best_estimator_.model
prediction=my_model.predict(testX)

# %%
print("\nPrediction Shape-",prediction.shape)
prediction_copies_array = np.repeat(prediction, 3, axis=-1)

# %%
pred=scaler.inverse_transform(np.reshape(prediction_copies_array,(len(prediction),3)))[:,2]

# %%
original_copies_array = np.repeat(testY, 3, axis=-1)

original_copies_array.shape

original=scaler.inverse_transform(np.reshape(original_copies_array,(len(testY),3)))[:,2]

# %%
print("Pred Values-- " ,pred.shape)
print("\nOriginal Values-- ",original.shape)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(original, color = 'red', label = 'Real')
plt.plot(pred, color = 'blue', label = 'Predicted')
plt.title('Prediction Compare')
plt.xlabel('Sequence Order')
if pred_name == 'Tn':
    plt.ylabel(f'Temperature {pred_name}')
elif pred_name == '(0,0)':
    plt.ylabel(f'Density {pred_name}')
else:
    plt.ylabel(f'{pred_name}')
plt.legend()
plt.savefig(f'./C_type_{fenzi_name}_Predition_{pred_name}', dpi=300)
plt.show()

# %% [markdown]
# # END!!!!

# %%
df_30_days_past=df_for_testing.iloc[-back_num:,:]
df_30_days_past.tail()

# %%
df_30_days_future=df[-back_num:]

# %%
df_30_days_future

# %%
# df_30_days_future=df_30_days_future[["distance","timeN","(0,0)"]]
df_30_days_future[f'{pred_name}'] = 0

# %%
df_30_days_future

# %%
old_scaled_array=scaler.transform(df_30_days_past)
new_scaled_array=scaler.transform(df_30_days_future)
new_scaled_df=pd.DataFrame(new_scaled_array)
new_scaled_df.iloc[:,2]=np.nan

# %%
full_df=pd.concat([pd.DataFrame(old_scaled_array),new_scaled_df]).reset_index().drop(["index"], axis=1)

# %%
full_df

# %%
full_df_scaled_array=full_df.values

# %%
full_df_scaled_array

# %%
full_df_scaled_array.shape

# %%
all_data=[]
time_step=back_num
for i in range(time_step,len(full_df_scaled_array)):
    data_x=[]
    data_x.append(full_df_scaled_array[i-time_step:i,0:full_df_scaled_array.shape[1]])
    data_x=np.array(data_x)
    prediction=my_model.predict(data_x)
    all_data.append(prediction)
    full_df.iloc[i,2]=prediction

# %%
all_data

# %%
new_array=np.array(all_data)
new_array=new_array.reshape(-1,1)
prediction_copies_array = np.repeat(new_array, 3, axis=-1)
y_pred_future_30_days = scaler.inverse_transform(np.reshape(prediction_copies_array,(len(new_array),3)))[:,2]

# %%
original_resul=np.array(df[-back_num:][f'{pred_name}'])

# %%
sds = [np.nan]*len(pred)
aagsa = np.concatenate((sds, y_pred_future_30_days), axis=0)

plt.plot(original, color = 'red', label = 'Real')
plt.plot(pred, color = 'blue', label = 'LSTM Fitting')
plt.plot(aagsa, color = 'green', label = 'Predicted')
plt.title('Prediction Compare')
plt.xlabel('Sequence Order')
if pred_name == 'Tn':
    plt.ylabel(f'Temperature {pred_name}')
elif pred_name == '(0,0)':
    plt.ylabel(f'Density {pred_name}')
else:
    plt.ylabel(f'{pred_name}')
# plt.yticks(np.arange(-3, -2, 0.1)) 
plt.legend()
plt.savefig(f'./C_type_{fenzi_name}_Predition_{pred_name}', dpi=300)
plt.show()

# %%
# # plt.plot(original_resul, color = 'red', label = 'Real')
# plt.plot(y_pred_future_30_days, color = 'blue', label = 'Predicted')
# plt.title('Predict Result')
# plt.xlabel('Sequence Order')
# if pred_name == 'Tn':
#     plt.ylabel(f'Temperature {pred_name}')
# elif pred_name == '(0,0)':
#     plt.ylabel(f'Density {pred_name}')
# else:
#     plt.ylabel(f'{pred_name}')
# plt.legend()
# plt.savefig(f'./C_type_{fenzi_name}_Predition_Result_{pred_name}', dpi=300)
# plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

# %%
my_model.save('/content/drive/MyDrive/NLU/Multivariate-time-series-forecasting-using-LSTM-main/Model_future_value.h5')
print('Model Saved!')

# %%
scaler

# %%
import pickle
scalerfile = '/content/drive/MyDrive/NLU/Multivariate-time-series-forecasting-using-LSTM-main/scaler_model_future_value.pkl'
pickle.dump(scaler, open(scalerfile, 'wb'))
